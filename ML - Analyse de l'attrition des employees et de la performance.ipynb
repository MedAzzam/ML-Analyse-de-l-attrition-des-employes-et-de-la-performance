# %% [markdown]
# # Titre du projet :
# ## Analyse de l'attrition des employés et de la performance à l'aide de Machine Learning
#
# ### 👉 Description :
#
# - **Dans ce projet, je vais analyser les données d'attrition des employés d'une entreprise afin de comprendre les raisons pour lesquelles les employés quittent l'entreprise et d'identifier les facteurs qui ont un impact sur la performance des employés. Pour ce faire, je vais construire un modèle d'machine learnig pour prédire l'attrition des employés et évaluer la performance des employés en fonction de différentes caractéristiques. Le projet impliquera la préparation des données, l'analyse exploratoire, l'ingénierie des fonctionnalités, la sélection du modèle et l'optimisation des hyperparamètres. Je vais évaluer les performances du modèle à l'aide de métriques telles que l'exactitude, la précision, le rappel et le score F1, et démontrer l'efficacité du modèle en l'appliquant à un ensemble de données du monde réel.**
#
#
# ### 👉 Pourquoi j'ai choisi ce projet :
#
# - **L'attrition des employés est un problème courant dans de nombreuses organisations, et il peut avoir un impact significatif sur leur succès à long terme. En construisant un modèle capable de prédire l'attrition des employés, je peux démontrer ma capacité à appliquer l'apprentissage automatique à un problème du monde réel qui présente des avantages commerciaux tangibles. En outre, la complexité technique du projet (y compris le prétraitement des données, l'ingénierie des caractéristiques et la sélection du modèle) démontrera ma maîtrise des techniques d'apprentissage automatique et impressionnera mon professeur avec mes compétences techniques. Enfin, en utilisant un ensemble de données du monde réel, je peux montrer la pertinence du projet pour le domaine de la gestion des ressources humaines et démontrer l'impact potentiel de l'apprentissage automatique sur les entreprises.**
#
# ### 👉 Dataset :
#
# - **Pour ce projet, j'utiliserai le jeu de données "IBM HR Analytics Employee Attrition & Performance" disponible sur Kaggle. Ce jeu de données contient des informations sur les employés d'IBM, y compris leur âge, leur sexe, leur statut marital, leur éducation, leur département, leur poste, leur salaire, leur satisfaction au travail, leur performance, leur nombre d'années d'expérience et leur historique de formation. Le jeu de données comprend également une variable binaire pour indiquer si l'employé a quitté l'entreprise ou non.**
#
# **Les variables du dataset sont les suivantes :**
#
# - Age: l'âge de l'employé
# - Attrition: le statut d'attrition (départ) de l'employé
# - BusinessTravel: fréquence des déplacements professionnels de l'employé
# - DailyRate: le salaire quotidien de l'employé
# - Department: le département dans lequel l'employé travaille
# - DistanceFromHome: la distance entre le domicile de l'employé et le lieu de travail
# - Education: le niveau d'éducation de l'employé (1 = 'Below College', 2 = 'College', 3 = 'Bachelor', 4 = 'Master', 5 = 'Doctor')
# - EducationField: le domaine d'études de l'employé
# - EmployeeCount: un compteur constant
# - EmployeeNumber: un identifiant unique pour chaque employé
# - EnvironmentSatisfaction: le niveau de satisfaction de l'employé à l'égard de son environnement de travail
# - Gender: le genre de l'employé
# - HourlyRate: le salaire horaire de l'employé
# - JobInvolvement: le niveau d'implication de l'employé dans son travail
# - JobLevel: le niveau de poste de l'employé dans l'entreprise
# - JobRole: le rôle de l'employé dans l'entreprise
# - JobSatisfaction: le niveau de satisfaction de l'employé à l'égard de son travail
# - MaritalStatus: l'état matrimonial de l'employé
# - MonthlyIncome: le salaire mensuel de l'employé
# - MonthlyRate: le taux de salaire mensuel de l'employé
# - NumCompaniesWorked: le nombre d'entreprises pour lesquelles l'employé a travaillé auparavant
# - Over18: une variable booléenne pour savoir si l'employé est majeur
# - OverTime: une variable booléenne pour savoir si l'employé travaille en heures supplémentaires
# - PercentSalaryHike: l'augmentation de salaire en pourcentage pour l'employé
# - PerformanceRating: la note de performance de l'employé
# - RelationshipSatisfaction: le niveau de satisfaction de l'employé à l'égard de ses relations avec les autres employés
# - StandardHours: les heures de travail standard pour l'employé
# - StockOptionLevel: le niveau d'options d'achat d'actions pour l'employé
# - TotalWorkingYears: le nombre total d'années travaillées par l'employé
# - TrainingTimesLastYear: le nombre de fois où l'employé a suivi une formation l'année dernière
# - WorkLifeBalance: l'équilibre entre vie professionnelle et vie privée de l'employé
# - YearsAtCompany: le nombre d'années que l'employé a travaillé dans l'entreprise
# - YearsInCurrentRole: le nombre d'années que l'employé a travaillé dans son rôle actuel
# - YearsSinceLastPromotion : représente le nombre d'années écoulées depuis la dernière promotion du collaborateur. Cette variable est continue et exprimée en années.
# - YearsWithCurrManager: représente le nombre d'années pendant lesquelles le collaborateur a travaillé sous la supervision de son manager actuel. Cette variable est continue et exprimée en années.
#
# ### 👉 Plan :

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Objectif
#
# - **Comprendre le mieux possible nos données (un petit pas en avant vaut mieux qu'un grand pas en arriere**)
# - **Développer une premiere strategie de modélisation**
#
# ###  Checklist de base (non-exhaustive):
# ###  Analyse de forme:
#
# - **👉 Identification de la target :**
#     - Attrition
# - **👉 Nombre de lignes et de colomns:**
#     - (1470, 35)
# - **👉 Types de variables:**
#     - qualitatives : 9, quantitatives: 26
#     - Apres la suppression des cols inutiles: qualitatives : 8, quantitatives: 23
# - **👉 Identifications des valeurs manquantes** :
#     - Il n'y a pas de valeurs manquantes
#
# ###  Analyse du fond:
#
# - **👉 Visualisation de la target**
#     - 84% NO
#     - 16% YES
# - **👉 Compréhention des différentes variables**
#     - Beaucoup de variables non standarisées
#     - **EmployeeCount, StandardHours, Over18** ont une seule valeur, ausssi **EmployeeNumber** a 1470 valeurs d'où il est mieux de les supprimer.
#     - **OverTime, Gender, Attrition** sont des variables binaire (0,1), les autres ont multipes valeurs possibles.
#     - On dévise notre dataset en colonnes discrets: **disc_col** , colonnes continues: **cont_col**, colonnes objects: **object_col**
#     - Apres la suppression des cols inutiles: qualitatives : 8, quantitatives: 23
#
#     - l'Age des employées est entre **18 et 60**
#
# - **👉 Visualisation des relations features-target (Histograme/Boxplot)**
# - **👉 Identification des outliers**

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

data = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# # Analyse de forme

# %%
df = data.copy()

# %%
print( f' notre dataset a {df.shape[0]} ligne et {df.shape[1]} colonnes')
# Out:
#  notre dataset a 1470 ligne et 35 colonnes

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.dtypes.value_counts()
# Out:
# int64     26
# object     9
# dtype: int64

# %%
plt.figure(figsize=(12,8))
df.dtypes.value_counts().plot.pie()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isna(), cbar= False)
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
(df.isna().sum()/df.shape[0]).sort_values(ascending=True)
# Out:
# Age                         0.0
# MonthlyRate                 0.0
# NumCompaniesWorked          0.0
# Over18                      0.0
# OverTime                    0.0
# PercentSalaryHike           0.0
# PerformanceRating           0.0
# MonthlyIncome               0.0
# RelationshipSatisfaction    0.0
# StockOptionLevel            0.0
# TotalWorkingYears           0.0
# TrainingTimesLastYear       0.0
# WorkLifeBalance             0.0
# YearsAtCompany              0.0
# YearsInCurrentRole          0.0
# StandardHours               0.0
# YearsSinceLastPromotion     0.0
# MaritalStatus               0.0
# JobRole                     0.0
# Attrition                   0.0
# BusinessTravel              0.0
# DailyRate                   0.0
# Department                  0.0
# DistanceFromHome            0.0
# Education                   0.0
# JobSatisfaction             0.0
# EducationField              0.0
# EmployeeNumber              0.0
# EnvironmentSatisfaction     0.0
# ...

# %%
print(f"Le nombre total de missing valeurs dans notre data: {df.isnull().sum().sum()}")
# Out:
# Le nombre total de missing valeurs dans notre data: 0

# %%
# print noms des colonnes  avec valeurs manquantes

cols_avec_manquantes = [col for col in df.columns
                     if df[col].isnull().any()]

print(f"les noms des colonnes  avec valeurs manquantes:\n{cols_avec_manquantes}")
# Out:
# les noms des colonnes  avec valeurs manquantes:
# []

# %% [markdown]
# ###  Analyse de forme:
#
# - **👉 Identification de la target :**
#     - Attrition
# - **👉 Nombre de lignes et de colomns:**
#     - (1470, 35)
#     - Apres la suppression des cols inutiles: (1470, 31)
# - **👉 Types de variables:**
#     - qualitatives : 9, quantitatives: 26
#     - Apres la suppression des cols inutiles: qualitatives : 8, quantitatives: 23
# - **👉 Identifications des valeurs manquantes** :
#     - Il n'y a pas de valeurs manquantes
#
#
# #### clc: les données semblent bonnes.

# %% [markdown]
# # Analyse du fond

# %% [markdown]
# ##  👉 Visualisation de la target
#
#   ### Exemen de col target

# %%
df['Attrition'].value_counts(normalize=True)
# Out:
# No     0.838776
# Yes    0.161224
# Name: Attrition, dtype: float64

# %% [markdown]
# ### Compréhention des différentes variables

# %%
for column in df.columns:
    print(f"{column}: nombres uniques de valeurs {df[column].nunique()}")
    print("==========================================================")
# Out:
# Age: nombres uniques de valeurs 43
# ...
# Attrition: nombres uniques de valeurs 2
# ...
# BusinessTravel: nombres uniques de valeurs 3
# ...
# DailyRate: nombres uniques de valeurs 886
# ...
# Department: nombres uniques de valeurs 3
# ...
# DistanceFromHome: nombres uniques de valeurs 29
# ...
# Education: nombres uniques de valeurs 5
# ...
# EducationField: nombres uniques de valeurs 6
# ...
# EmployeeCount: nombres uniques de valeurs 1
# ...
# EmployeeNumber: nombres uniques de valeurs 1470
# ...
# EnvironmentSatisfaction: nombres uniques de valeurs 4
# ...
# Gender: nombres uniques de valeurs 2
# ...
# HourlyRate: nombres uniques de valeurs 71
# ...
# JobInvolvement: nombres uniques de valeurs 4
# ...
# JobLevel: nombres uniques de valeurs 5
# ...
# JobRole: nombres uniques de valeurs 9
# ...
# JobSatisfaction: nombres uniques de valeurs 4
# ...
# MaritalStatus: nombres uniques de valeurs 3
# ...
# MonthlyIncome: nombres uniques de valeurs 1349
# ...
# MonthlyRate: nombres uniques de valeurs 1427
# ...
# NumCompaniesWorked: nombres uniques de valeurs 10
# ...
# Over18: nombres uniques de valeurs 1
# ...

# %% [markdown]
# - **EmployeeCount, StandardHours, Over18** ont une seule valeur, ausssi **EmployeeNumber** a 1470 valeurs d'où il est mieux de les supprimer car ils sont inutiles.

# %% [markdown]
# ### Elimination des colonnes inutiles

# %%
df = df.drop(['EmployeeCount','StandardHours', 'Over18', 'EmployeeNumber'], axis=1)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %% [markdown]
# ### Variables Quantitatives

# %%
disc_col = []
for column in df.columns:
    if df[column].dtypes != object and df[column].nunique() < 30:
        print(f"{column} : {df[column].unique()}")
        disc_col.append(column)
        print("====================================")
# Out:
# DistanceFromHome : [ 1  8  2  3 24 23 27 16 15 26 19 21  5 11  9  7  6 10  4 25 12 18 29 22
#  14 20 28 17 13]
# ...
# Education : [2 1 4 3 5]
# ...
# EnvironmentSatisfaction : [2 3 4 1]
# ...
# JobInvolvement : [3 2 4 1]
# ...
# JobLevel : [2 1 3 4 5]
# ...
# JobSatisfaction : [4 2 3 1]
# ...
# NumCompaniesWorked : [8 1 6 9 0 4 5 2 7 3]
# ...
# PercentSalaryHike : [11 23 15 12 13 20 22 21 17 14 16 18 19 24 25]
# ...
# PerformanceRating : [3 4]
# ...
# RelationshipSatisfaction : [1 4 2 3]
# ...
# StockOptionLevel : [0 1 3 2]
# ...
# TrainingTimesLastYear : [0 3 2 5 1 4 6]
# ...
# WorkLifeBalance : [1 3 2 4]
# ...
# YearsInCurrentRole : [ 4  7  0  2  5  9  8  3  6 13  1 15 14 16 11 10 12 18 17]
# ...
# YearsSinceLastPromotion : [ 0  1  3  2  7  4  8  6  5 15  9 13 12 10 11 14]
# ...
# YearsWithCurrManager : [ 5  7  0  2  6  8  3 11 17  1  4 12  9 10 15 13 16 14]
# ...

# %%
cont_col = []
for column in df.columns:
    if df[column].dtypes != object and df[column].nunique() > 30:
        print(f"{column} : Minimum: {df[column].min()}, Maximum: {df[column].max()}")
        cont_col.append(column)
        print("====================================")
# Out:
# Age : Minimum: 18, Maximum: 60
# ...
# DailyRate : Minimum: 102, Maximum: 1499
# ...
# EmployeeNumber : Minimum: 1, Maximum: 2068
# ...
# HourlyRate : Minimum: 30, Maximum: 100
# ...
# MonthlyIncome : Minimum: 1009, Maximum: 19999
# ...
# MonthlyRate : Minimum: 2094, Maximum: 26999
# ...
# TotalWorkingYears : Minimum: 0, Maximum: 40
# ...
# YearsAtCompany : Minimum: 0, Maximum: 40
# ...

# %% [markdown]
# ### Variables Qualitatives

# %%
object_col = []
for column in df.columns:
    if df[column].dtype == object and len(df[column].unique()) <= 30:
        object_col.append(column)
        print(f"{column} : {df[column].unique()}")
        print(df[column].value_counts())
        print("====================================")
object_col.remove('Attrition')
# Out:
# Attrition : ['Yes' 'No']
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# ...
# BusinessTravel : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# ...
# Department : ['Sales' 'Research & Development' 'Human Resources']
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# ...
# EducationField : ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
# ...
# Gender : ['Female' 'Male']
# Male      882
# Female    588
# Name: Gender, dtype: int64
# ...
# JobRole : ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
# ...

# %% [markdown]
# Identifié les besoins pour l'encodage catégorique :
#
# - **Attrition (2 valeurs):** nécessite un encodage binaire pour encoder les valeurs catégoriques ('Oui'/'Non') en valeurs numériques.
# - **BusinessTravel (3 valeurs)**: est une variable ordinale et nécessite un encodage ordinal.
# - **Department (3 valeurs):** est une variable nominale et nécessite un encodage one-hot.
# - **EducationField (6 valeurs):** est une variable nominale et nécessite un autre encodage catégorique.
# - **Gender (2 valeurs):** nécessite un encodage binaire.
# - **JobRole (9 valeurs):** est une variable nominale et nécessite un autre encodage catégorique.
# - **MaritalStatus (3 valeurs):** est une variable nominale et nécessite un encodage one-hot.
# - **OverTime (2 valeurs):** nécessitent un encodage binaire.
#
#
# - **Variables ordinales :** variables catégorielles ayant un ordre clair dans les valeurs.
# - **Variables nominales :** variables catégorielles sans ordre dans les valeurs.

# %% [markdown]
# ## 👉 Relations features-target

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# - **Dans cette section, On a effectué l'analyse univariée, c'est-à-dire j'ai analysé la plage ou la distribution des valeurs que prennent différentes features. Pour mieux analyser les résultats, on a tracé différents graphiques et visualisations lorsque cela était nécessaire.**

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# std                   1.093082    20.329428        0.711561     1.106940
# min                   1.000000    30.000000        1.000000     1.000000
# ...

# %% [markdown]
# - **Analysons d'abord les différentes caractéristiques numériques. Pour ce faire, nous pouvons tracer un boxplot montrant toutes les features numériques.**

# %%
sns.factorplot(data=df,kind='box',size=10,aspect=3)

# %% [markdown]
# - **Notez que toutes les caractéristiques ont des échelles assez différentes et que donc tracer un boxplot n'est pas une bonne idée. À la place, nous pouvons tracer des histogrammes de différentes caractéristiques distribuées en continu.**
#
# - **Nous pouvons également tracer un kdeplot montrant la distribution de la caractéristique. Ci-dessous, j'ai tracé un kdeplot pour la caractéristique 'Age'. De même, nous pouvons tracer pour d'autres caractéristiques numériques également. Nous pouvons également utiliser un distplot de la bibliothèque seaborn.**

# %%
sns.kdeplot(df['Age'],shade=True,color='#ff4125')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# - **De même, nous pouvons faire cela pour toutes les caractéristiques numériques. Ci-dessous, j'ai tracé les sous-graphiques pour les autres caractéristiques.**

# %%
fig,ax = plt.subplots(5,2, figsize=(9,9))                
sns.distplot(df['TotalWorkingYears'], ax = ax[0,0]) 
sns.distplot(df['MonthlyIncome'], ax = ax[0,1]) 
sns.distplot(df['YearsAtCompany'], ax = ax[1,0]) 
sns.distplot(df['DistanceFromHome'], ax = ax[1,1]) 
sns.distplot(df['YearsInCurrentRole'], ax = ax[2,0]) 
sns.distplot(df['YearsWithCurrManager'], ax = ax[2,1]) 
sns.distplot(df['YearsSinceLastPromotion'], ax = ax[3,0]) 
sns.distplot(df['PercentSalaryHike'], ax = ax[3,1]) 
sns.distplot(df['YearsSinceLastPromotion'], ax = ax[4,0]) 
sns.distplot(df['TrainingTimesLastYear'], ax = ax[4,1]) 
plt.tight_layout()
plt.show()

# %% [markdown]
# - **Analysons maintenant les différentes caractéristiques catégorielles. Notez que dans ces cas, la meilleure façon est d'utiliser un count plot pour montrer le nombre relatif d'observations de différentes catégories.**

# %%
for col in object_col:
    plt.figure(figsize=(12,8))
    sns.factorplot(data=df,kind='count',size=5,aspect=3,x=col)

# %% [markdown]
# #### Notes:
#
# - **Notez que le nombre d'observations appartenant à la catégorie "Non" est beaucoup plus élevé que celui appartenant à la catégorie "Oui". Nous avons donc des classes déséquilibrées. Pour résoudre ce type de problème, nous devons utiliser des techniques de over-sampling ou de under-sampling. Je reviendrai sur ce point plus tard.**
#
# - **Les hommes present un grand nombre.**
#
# - **Le graphique de BusinessTravel montre clairement que la plupart des personnes appartiennent à la classe "Travel_Rarely". Cela indique que la plupart des gens n'ont pas eu un emploi qui leur demandait de voyager fréquemment.**

# %%
num_disc=['Education','EnvironmentSatisfaction',
          'JobInvolvement','JobSatisfaction','WorkLifeBalance',
          'RelationshipSatisfaction','PerformanceRating']

for col in num_disc:
    plt.figure(figsize=(12,8))
    sns.factorplot(data=df,kind='count',size=5,aspect=3,x=col)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ### Visualiser les Features en fonction de 'Target' variable.
#
# ###  Age
#
# - **Age est un variable continue donc on peut utiliser boxplot pour le ploter contre Attrition**

# %%
sns.factorplot(data=df,y='Age',x='Attrition',size=5,aspect=1,kind='box')

# %% [markdown]
# - **Notez que l'âge médian ainsi que l'âge maximum des personnes ayant une attrition "No" sont plus élevés que ceux de la catégorie "Yes". Cela montre que les personnes plus âgées ont moins tendance à quitter l'organisation, ce qui est logique car elles ont peut-être trouvé leur place dans l'organisation.**

# %% [markdown]
# ### Department
#
# - **Notez que l'Attrition (Target) ainsi que le Département sont tous deux des variables catégorielles. Dans de tels cas, une cross-tabulation (table de contingence) est la manière la plus raisonnable d'analyser les tendances. Cela montre clairement le nombre d'observations pour chaque classe, ce qui facilite l'analyse des résultats.**

# %%
df.Department.value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
sns.factorplot(data=df,kind='count',x='Attrition',col='Department')

# %%
pd.crosstab(columns=[df.Attrition],index=[df.Department],margins=True,normalize='index') # mettons normalize=index pour avoir des %.
# Out:
# Attrition                     No       Yes
# Department
# Human Resources         0.809524  0.190476
# Research & Development  0.861602  0.138398
# Sales                   0.793722  0.206278
# All                     0.838776  0.161224

# %% [markdown]
# - **Notez que la plupart des observations correspondent à "No", comme nous l'avons vu précédemment.    Environ 81 % des personnes travaillant dans les ressources humaines ne souhaitent pas quitter l'organisation et seulement 19 % souhaitent partir. Des conclusions similaires peuvent être tirées pour les autres départements à partir de la cross-tabulation. ci-dessus.**

# %% [markdown]
# ### Gender

# %%
pd.crosstab(columns=[df.Attrition],index=[df.Gender],margins=True,normalize='index')
# Out:
# Attrition        No       Yes
# Gender
# Female     0.852041  0.147959
# Male       0.829932  0.170068
# All        0.838776  0.161224

# %% [markdown]
# - **Environ 85 % des femmes souhaitent rester dans l'organisation, tandis que seulement 15 % veulent la quitter. Dans l'ensemble, 83 % des employés souhaitent rester dans l'organisation, tandis que seulement 16 % souhaitent la quitter ou quitter l'entreprise.**

# %% [markdown]
# ### Job Level

# %%
pd.crosstab(columns=[df.Attrition],index=[df.JobLevel],margins=True,normalize='index')
# Out:
# Attrition        No       Yes
# JobLevel
# 1          0.736648  0.263352
# 2          0.902622  0.097378
# 3          0.853211  0.146789
# 4          0.952830  0.047170
# 5          0.927536  0.072464
# All        0.838776  0.161224

# %% [markdown]
# - **Les personnes du niveau de poste 4 ont un pourcentage très élevé pour un "No" et un faible pourcentage pour un "Yes". Des inférences similaires peuvent être tirées pour les autres niveaux de poste.**

# %% [markdown]
# ### Monthly Income

# %%
sns.factorplot(data=df,kind='bar',x='Attrition',y='MonthlyIncome')

# %% [markdown]
# - **Notez que le salaire moyen pour la classe "No" est assez élevé, ce qui est évident car ceux qui gagnent bien ne seront certainement pas disposés à quitter l'organisation. De même, les employés qui ne gagnent probablement pas beaucoup chercheront certainement à changer d'entreprise.**

# %% [markdown]
# ### Job Satisfaction

# %%
sns.factorplot(data=df,kind='count',x='Attrition',col='JobSatisfaction')

# %%
pd.crosstab(columns=[df.Attrition],index=[df.JobSatisfaction],margins=True,normalize='index')
# Out:
# Attrition              No       Yes
# JobSatisfaction
# 1                0.771626  0.228374
# 2                0.835714  0.164286
# 3                0.834842  0.165158
# 4                0.886710  0.113290
# All              0.838776  0.161224

# %% [markdown]
# - **Notez que cela montre une tendance intéressante. Notez que pour des valeurs plus élevées de satisfaction au travail (c'est-à-dire plus une personne est satisfaite de son travail), un pourcentage moins élevé d'entre eux répondent "Yes", ce qui est assez évident car les travailleurs très satisfaits ne voudront évidemment pas quitter l'organisation.**

# %% [markdown]
# ### Environment Satisfaction

# %%
pd.crosstab(columns=[df.Attrition],index=[df.EnvironmentSatisfaction],margins=True,normalize='index')
# Out:
# Attrition                      No       Yes
# EnvironmentSatisfaction
# 1                        0.746479  0.253521
# 2                        0.850174  0.149826
# 3                        0.863135  0.136865
# 4                        0.865471  0.134529
# All                      0.838776  0.161224

# %% [markdown]
# - **Encore une fois, nous pouvons remarquer que le pourcentage relatif de "No" est plus élevé chez les personnes ayant un niveau plus élevé de satisfaction environnementale.**

# %% [markdown]
# ### Job Involvement

# %%
pd.crosstab(columns=[df.Attrition],index=[df.JobInvolvement],margins=True,normalize='index')
# Out:
# Attrition             No       Yes
# JobInvolvement
# 1               0.662651  0.337349
# 2               0.810667  0.189333
# 3               0.855991  0.144009
# 4               0.909722  0.090278
# All             0.838776  0.161224

# %% [markdown]
# ### Work Life Balance

# %%
pd.crosstab(columns=[df.Attrition],index=[df.WorkLifeBalance],margins=True,normalize='index')
# Out:
# Attrition              No       Yes
# WorkLifeBalance
# 1                0.687500  0.312500
# 2                0.831395  0.168605
# 3                0.857783  0.142217
# 4                0.823529  0.176471
# All              0.838776  0.161224

# %% [markdown]
# - **Encore une fois, nous remarquons une tendance similaire : les personnes ayant un meilleur équilibre entre vie professionnelle et vie privée ne veulent pas quitter l'organisation.**

# %% [markdown]
# ### RelationshipSatisfaction

# %%
pd.crosstab(columns=[df.Attrition],index=[df.RelationshipSatisfaction],margins=True,normalize='index')
# Out:
# Attrition                       No       Yes
# RelationshipSatisfaction
# 1                         0.793478  0.206522
# 2                         0.851485  0.148515
# 3                         0.845316  0.154684
# 4                         0.851852  0.148148
# All                       0.838776  0.161224

# %% [markdown]
# - **Remarquez que j'ai tracé uniquement quelques-unes des caractéristiques importantes par rapport à notre variable 'Target', c'est-à-dire l'attrition dans notre cas. De même, nous pouvons tracer d'autres caractéristiques par rapport à la variable 'Target' et analyser les tendances, c'est-à-dire comment la caractéristique affecte la variable 'Target'.**

# %% [markdown]
# ## Corelation b/w Features

# %%
#corelation matrix.
cor_mat= df.corr()
plt.figure(figsize=(30,12))
sns.heatmap(data=cor_mat,square=True,annot=True,cbar=True)
# Out:
# <AxesSubplot:>

# %%
selected_cols = ['YearsAtCompany', 'YearsWithCurrManager','PercentSalaryHike', 
                 'PerformanceRating', 'YearsInCurrentRole', 'TotalWorkingYears',
                 'Age', 'JobLevel', 'MonthlyIncome']
selected_df = df[selected_cols]
corr_matrix = selected_df.corr()
print(corr_matrix)
# Out:
#                       YearsAtCompany  YearsWithCurrManager  PercentSalaryHike  \
# YearsAtCompany              1.000000              0.769212          -0.035991
# YearsWithCurrManager        0.769212              1.000000          -0.011985
# PercentSalaryHike          -0.035991             -0.011985           1.000000
# PerformanceRating           0.003435              0.022827           0.773550
# YearsInCurrentRole          0.758754              0.714365          -0.001520
# TotalWorkingYears           0.628133              0.459188          -0.020608
# Age                         0.311309              0.202089           0.003634
# JobLevel                    0.534739              0.375281          -0.034730
# MonthlyIncome               0.514285              0.344079          -0.027269
#
#                       PerformanceRating  YearsInCurrentRole  \
# YearsAtCompany                 0.003435            0.758754
# YearsWithCurrManager           0.022827            0.714365
# ...

# %%
plt.figure(figsize=(30,12))
sns.heatmap(data=corr_matrix,square=True,annot=True,cbar=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **DÉCOMPOSITION**
#
# - Tout d'abord, l'appel de la méthode .corr() sur un dataframe pandas renvoie un dataframe de corrélation contenant les valeurs de corrélation entre les différentes attributs.Dans l'étape suivante, nous passons les paramètres nécessaires à la fonction heatmap.
#
# - Data = le dataframe de corrélation contenant les valeurs de "CORRÉLATION".
#
# - SQUARE = pour montrer chaque unité individuelle sous forme de carré.
#
# - ANNOT = indique si les valeurs doivent être affichées au-dessus du carré ou non. Pour afficher, passez True ou la cor_mat.
#
# - CBAR = pour afficher ou non la barre latérale.
#
# **QUELQUES INFÉRENCES À PARTIR DE HEATMAP CI-DESSUS**
#
# - La relation avec soi-même, c'est-à-dire d'une caractéristique avec elle-même, est égale à 1, comme prévu.
#
# - JobLevel est très lié à l'Age, comme prévu, car les employés âgés ont généralement tendance à occuper des postes plus élevés dans l'entreprise.
#
# - MonthlyIncome est très fortement lié au JobLevel , comme prévu, car les employés seniors gagneront certainement plus.
#
# - PerformanceRating  est fortement liée à PercentSalaryHike, ce qui est assez évident.
#
# - Notez également que TotalWorkingYears est fortement lié au JobLevel , comme prévu, car les employés seniors doivent avoir travaillé pendant une plus longue période.
#
# - YearsWithCurrManager est fortement lié au YearsAtCompany.
#
# - YearsAtCompany est lié au YearsInCurrentRole.
#
# - Notez que nous pouvons supprimer certaines caractéristiques fortement corrélées car elles ajoutent de la redondance au modèle, mais comme la corrélation est très faible en général, gardons toutes les caractéristiques pour l'instant. En cas de features hautement corrélées, nous pouvons utiliser quelque chose comme l'Analyse en Composantes Principales (PCA) pour réduire notre espace de features.

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # Pre-processing:
#
#
# ## Objectif :
#
# #### Transformer le data pour le mettre dans un format propice au Machine Learning.
#
# ## Checklist de base (non-exhaustive):
#
# ### Processus:
#
# #### 👉 Creation du Train set / Test set
#
# #### 👉 Elimination des NaN: dropna(), imputation, colonnes >>vides<<
#
# #### 👉 Ecodage
#
# #### 👉 Suppression des outliers néfastes au modèle
#
# #### 👉 Feature Selection
#
# #### 👉 Feature Engineering
#
# #### 👉 Feature Scaling

# %% [markdown]
# # 👉 Ecodage

# %%
df1 = data.drop(['EmployeeCount','StandardHours', 'Over18', 'EmployeeNumber'], axis=1)

# %%
df1.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
#Binary Encoding

def copy_df(df1):
    
    df1['Attrition'] = df1['Attrition'].replace({'No': 0, 'Yes': 1})
    df1['Gender'] = df1['Gender'].replace({'Female': 0, 'Male': 1})
    df1['OverTime'] = df1['OverTime'].replace({'No': 0, 'Yes': 1})
    
    return df1

print("la fonction est creer")
# Out:
# la fonction est creer

# %%
copy_df(df1).head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
cat_col=df1.select_dtypes(include='object')
for col in cat_col.columns:
    print(col ,":" ,len(cat_col[col].unique()))
# Out:
# Attrition : 2
# BusinessTravel : 3
# Department : 3
# EducationField : 6
# Gender : 2
# JobRole : 9
# MaritalStatus : 3
# OverTime : 2

# %%
#Ordinal Encoding

def copy_df(df1):
     
    df1['BusinessTravel'] = df1['BusinessTravel'].replace({'Non-Travel': 0, 
                                                           'Travel_Rarely': 1,
                                                           'Travel_Frequently': 2})
    
    return df1

print("la fonction est creer")
# Out:
# la fonction est creer

# %%
copy_df(df1).head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               1       1102           2                 1
# 1   49          0               2        279           1                 8
# 2   37          1               1       1373           1                 2
# 3   33          0               2       1392           1                 3
# 4   27          0               1        591           1                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          2               1                        2       0  ...
# 1          1               1                        3       1  ...
# 2          2               4                        4       1  ...
# 3          4               1                        4       0  ...
# 4          1               3                        1       1  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
# Nominal Encoding

# nos valeurs
print(f"Department:\n {(cat_col['Department'].unique())}")
print("\n")
print(f"MaritalStatus:\n {(cat_col['MaritalStatus'].unique())}")
print("\n")
print(f"EducationField:\n {(cat_col['EducationField'].unique())}")
print("\n")
print(f"JobRole:\n {(cat_col['JobRole'].unique())}")
# Out:
# Department:
#  ['Sales' 'Research & Development' 'Human Resources']
#
#
# MaritalStatus:
#  ['Single' 'Married' 'Divorced']
#
#
# EducationField:
#  ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
#
#
# JobRole:
#  ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']

# %%
def transform(feature):
    le=LabelEncoder()
    df1[feature]=le.fit_transform(df1[feature])
    print(le.classes_)

# %%
cat_col_ = cat_col.drop('BusinessTravel', axis=1)
cat_col_


for col in cat_col_.columns:
    transform(col)
# Out:
# ['No' 'Yes']
# ['Human Resources' 'Research & Development' 'Sales']
# ['Human Resources' 'Life Sciences' 'Marketing' 'Medical' 'Other'
#  'Technical Degree']
# ['Female' 'Male']
# ['Healthcare Representative' 'Human Resources' 'Laboratory Technician'
#  'Manager' 'Manufacturing Director' 'Research Director'
#  'Research Scientist' 'Sales Executive' 'Sales Representative']
# ['Divorced' 'Married' 'Single']
# ['No' 'Yes']

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   int64
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int64
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   int64
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   int64
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   int64
# ...

# %%
df1.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               1       1102           2                 1
# 1   49          0               2        279           1                 8
# 2   37          1               1       1373           1                 2
# 3   33          0               2       1392           1                 3
# 4   27          0               1        591           1                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          2               1                        2       0  ...
# 1          1               1                        3       1  ...
# 2          2               4                        4       1  ...
# 3          4               1                        4       0  ...
# 4          1               3                        1       1  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %% [markdown]
# # 👉 Creation du Train set / Test set

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from imblearn.over_sampling import RandomOverSampler

# %%
"""scaler=StandardScaler()
scaled_df=scaler.fit_transform(df1.drop('Attrition',axis=1))
X=scaled_df
y=df1['Attrition'].to_numpy()"""

X = df1.drop('Attrition', axis=1)
y = df1['Attrition']


oversample = RandomOverSampler()
X,y  = oversample.fit_resample(X,y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %% [markdown]
# # Modeling:
#
#
# ## Objectif :
#
# #### Développer un modèle de Machine Learning qui réponde à l'objectif final.
#
# ## Checklist de base (non-exhaustive):
#
# ### Processus:
#
# #### 👉 Définir une fonction d'évaluation
#
# #### 👉 Entrainement de différents modèles
#
# #### 👉 Optimisation
#
# #### 👉 Learning Curve et prise de décision

# %% [markdown]
# # 👉 Modelisation

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest, f_classif

# %%
model = DecisionTreeClassifier(random_state=0)

model1 = RandomForestClassifier(random_state=0)

model2 = make_pipeline(SelectKBest(f_classif, k=10),
                      DecisionTreeClassifier(random_state=0))

model3 = make_pipeline(SelectKBest(f_classif, k=19),
                      RandomForestClassifier(random_state=0))

model4 = make_pipeline(SelectKBest(f_classif, k=10),StandardScaler(),
                      SVC(random_state=0))

# %% [markdown]
# # 👉 Définir une fonction d'évaluation

# %%
from sklearn.metrics import f1_score, confusion_matrix, classification_report

from sklearn.model_selection import learning_curve

# %%
def evaluation(model):
    
    model.fit(X_train, y_train)
    ypred = model.predict(X_test)
    
    print(confusion_matrix(y_test, ypred))
    print(classification_report(y_test, ypred))
    
    N, train_score, val_score = learning_curve(model, X_train, y_train,
                                              cv=4, scoring='f1',
                                               train_sizes=np.linspace(0.1, 1, 10))
    
    
    plt.figure(figsize=(12, 8))
    plt.plot(N, train_score.mean(axis=1), label='train score')
    plt.plot(N, val_score.mean(axis=1), label='validation score')
    plt.legend()

# %%
evaluation(model)
# Out:
# [[278  32]
#  [ 37  21]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89       310
#            1       0.40      0.36      0.38        58
#
#     accuracy                           0.81       368
#    macro avg       0.64      0.63      0.63       368
# weighted avg       0.81      0.81      0.81       368

# %%
pd.DataFrame(model.feature_importances_, index=X_train.columns).plot.bar(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 👉 Feature Selection

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# - **La sélection de features est l'une des principales étapes de la phase de pre-processing car les features que nous choisissons affectent directement les performances du modèle. Alors que certaines features semblent être moins utiles en termes de contexte, d'autres semblent également utiles. Plus nous utilisons de bonnes features, meilleures seront les performances de notre modèle.**

# %%
importances = pd.DataFrame(model.feature_importances_, index=X_train.columns, columns=['Importance'])
importances_triers = importances.sort_values('Importance', ascending=False)

print(importances_triers)
# Out:
#                           Importance
# TotalWorkingYears           0.093886
# MonthlyRate                 0.088936
# HourlyRate                  0.068031
# MonthlyIncome               0.058795
# JobLevel                    0.054526
# DistanceFromHome            0.054282
# DailyRate                   0.049893
# JobRole                     0.047069
# RelationshipSatisfaction    0.043576
# MaritalStatus               0.043178
# EnvironmentSatisfaction     0.042432
# OverTime                    0.042201
# YearsWithCurrManager        0.039772
# YearsSinceLastPromotion     0.036611
# YearsAtCompany              0.033500
# Age                         0.031334
# JobInvolvement              0.030867
# WorkLifeBalance             0.023887
# Department                  0.020270
# TrainingTimesLastYear       0.015024
# EducationField              0.014116
# Education                   0.011117
# PercentSalaryHike           0.010656
# YearsInCurrentRole          0.010376
# ...

# %%
important_cols = ['TotalWorkingYears', 'MonthlyRate', 'HourlyRate', 'MonthlyIncome', 'JobLevel', 
                  'DistanceFromHome', 'DailyRate', 'JobRole', 'Attrition']

df2 = df2[important_cols]

# %%
len(df2.columns)
# Out:
# 9

# %%
X2 = df2.drop('Attrition', axis=1)
y2 = df2['Attrition']


X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.25, 
                                                    random_state=0)

# %%
df2.columns
# Out:
# Index(['TotalWorkingYears', 'MonthlyRate', 'HourlyRate', 'MonthlyIncome',
#        'JobLevel', 'DistanceFromHome', 'DailyRate', 'JobRole', 'Attrition'],
#       dtype='object')

# %%
def evaluation2(model):
    
    model.fit(X2_train, y2_train)
    ypred = model.predict(X2_test)
    
    print(confusion_matrix(y2_test, ypred))
    print(classification_report(y2_test, ypred))
    
    N, train_score, val_score = learning_curve(model, X2_train, y2_train,
                                              cv=4, scoring='f1',
                                               train_sizes=np.linspace(0.1, 1, 10))
    
    
    plt.figure(figsize=(12, 8))
    plt.plot(N, train_score.mean(axis=1), label='train score')
    plt.plot(N, val_score.mean(axis=1), label='validation score')
    plt.legend()

# %%
evaluation2(model)
# Out:
# [[255  55]
#  [ 43  15]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84       310
#            1       0.21      0.26      0.23        58
#
#     accuracy                           0.73       368
#    macro avg       0.53      0.54      0.54       368
# weighted avg       0.75      0.73      0.74       368

# %%
evaluation(model1)
# Out:
# [[307   3]
#  [ 49   9]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       310
#            1       0.75      0.16      0.26        58
#
#     accuracy                           0.86       368
#    macro avg       0.81      0.57      0.59       368
# weighted avg       0.84      0.86      0.82       368

# %%
pd.DataFrame(model1.feature_importances_, index=X_train.columns).plot.bar(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
evaluation(model2)
# Out:
# [[258  52]
#  [ 34  24]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.86       310
#            1       0.32      0.41      0.36        58
#
#     accuracy                           0.77       368
#    macro avg       0.60      0.62      0.61       368
# weighted avg       0.79      0.77      0.78       368

# %% [markdown]
# ### APRES l'Oversampling

# %%
#model1
evaluation(model1)
# Out:
# [[284  15]
#  [  3 315]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97       299
#            1       0.95      0.99      0.97       318
#
#     accuracy                           0.97       617
#    macro avg       0.97      0.97      0.97       617
# weighted avg       0.97      0.97      0.97       617

# %%
#model2
evaluation(model2)
# Out:
# [[241  58]
#  [  2 316]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.81      0.89       299
#            1       0.84      0.99      0.91       318
#
#     accuracy                           0.90       617
#    macro avg       0.92      0.90      0.90       617
# weighted avg       0.92      0.90      0.90       617

# %%
#model3
evaluation(model3)
# Out:
# [[286  13]
#  [  3 315]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97       299
#            1       0.96      0.99      0.98       318
#
#     accuracy                           0.97       617
#    macro avg       0.97      0.97      0.97       617
# weighted avg       0.97      0.97      0.97       617

# %%
#model4
evaluation(model4)
# Out:
# [[228  71]
#  [ 88 230]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.76      0.74       299
#            1       0.76      0.72      0.74       318
#
#     accuracy                           0.74       617
#    macro avg       0.74      0.74      0.74       617
# weighted avg       0.74      0.74      0.74       617

# %% [markdown]
# # Conclusion:
#
# - **On voit que les models 1 et 3 donnent des bonnes résultat, cela d'apres l'observation de nos metrics (recall, precision, f1-score, accuracy).**
# - **Mais on va choisir le model3, car il est un peu plus performant.**

# %%
from sklearn.metrics import precision_recall_curve


model3.fit(X_train, y_train)
ypred3 = model3.predict(X_test)

precision, recall, threshold = precision_recall_curve(y_test, ypred3)

# %%
plt.plot(threshold, precision[:-1], label='precision')
plt.plot(threshold, recall[:-1], label='recall')
plt.legend()

# %%
ypred3_proba = model3.predict_proba(X_test)[:, 1]

print(ypred3_proba[88])

print("===================")

print(ypred3[88])
# Out:
# 0.93
# ...
# 1

# %%
def model_final(model3, X):
    
    ypred3 = model3.predict(X)    
    
    return ypred3

# %%
X_test.iloc[88, :]
# Out:
# Age                            33
# BusinessTravel                  1
# DailyRate                     603
# Department                      2
# DistanceFromHome                9
# Education                       4
# EducationField                  2
# EnvironmentSatisfaction         1
# Gender                          0
# HourlyRate                     77
# JobInvolvement                  3
# JobLevel                        2
# JobRole                         7
# JobSatisfaction                 1
# MaritalStatus                   2
# MonthlyIncome                8224
# MonthlyRate                 18385
# NumCompaniesWorked              0
# OverTime                        1
# PercentSalaryHike              17
# PerformanceRating               3
# RelationshipSatisfaction        1
# StockOptionLevel                0
# TotalWorkingYears               6
# TrainingTimesLastYear           3
# WorkLifeBalance                 3
# YearsAtCompany                  5
# ...
